# %% [markdown]
# <a href="https://colab.research.google.com/github/Rijin-shaji/Code/blob/main/AI_Resume_Scanner%20for%20IT%20Jobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2

# %% [markdown]
# Reading every pages in a pdf

# %%
import PyPDF2

file = open("/content/Python Interview Questions.pdf", "rb")
filereader = PyPDF2.PdfReader(file)
ct=len(filereader.pages)
text = ""
for i in range(ct):
  page = filereader.pages[i]
  text += page.extract_text()

formatted_text = text.replace('\n', '\n')

print(formatted_text)
# Out:
#  Python Interview Questions
# 1. Explain Python?
# Answer:
#  Python is a highly comprehensive, interactive, and object -oriented script writing language. It
# was developed to make the content highly readable among net surfers. Python makes use of
# various English keywords other than just punctuations.
# 2. What are the distinct features of Python?
# Answer:
# ● Structured and functional programming are supported.
# ● It can be compiled to byte -code for creating larger applications.
# ● Develops high -level dynamic data types.
# ● Supports checking of dynamic data types.
# ● Applies automated garbage collection.
# ● It could be used effectively along with Java, COBRA, C, C++, ActiveX, and COM.
# 3. What is the Python path?
# Answer:
#  A Python path tells the Python interpreter to locate the module files that can be imported
# into the program. It includes the Python source library directory and source code directory.
# 4. What are the supported standard data types in Python?
# ...

# %% [markdown]
# To upload unknown file

# %%
import PyPDF2
from google.colab import files
import io
import re

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

  file_content = uploaded[fn]

  pdf_file = io.BytesIO(file_content)

  filereader = PyPDF2.PdfReader(pdf_file)
  total_pages = len(filereader.pages)
  all_text = ""

  for page_num in range(total_pages):
      page = filereader.pages[page_num]
      all_text += page.extract_text()

  clean_text = all_text.lower()
  clean_text = re.sub(r'\s+', ' ', clean_text)
  clean_text = re.sub(r'[^\x00-\x7F]+', ' ', clean_text)


  skills = [
    "python", "java", "c++", "sql", "javascript","APIs",
    "machine learning", "deep learning", "nlp", "computer vision",
    "pytorch", "tensorflow", "hugging face", "langchain",
    "data analysis", "data visualization", "excel",
    "react", "node.js", "html", "css"
  ]
  skills_lower = [skill.lower() for skill in skills]

  found_skills = []

  for skill in skills_lower:
    if skill in clean_text:
        found_skills.append(skill)

  print("Skills found in resume:", found_skills)

  job_description = """
  We are looking for a Python developer with experience in machine learning, NLP, APIs and SQL.
  Knowledge of PyTorch or TensorFlow is a plus.
  """
  d_skills = []

for skill in skills_lower:
    if skill in job_description.lower():
        d_skills.append(skill)

print("Skills required in job description:", d_skills)

common_skills = set(found_skills) & set(d_skills)

match_score = (len(common_skills) / len(d_skills)) * 100

print("Skills match:", common_skills)
print(f"Match score: {match_score:.2f}%")

missing_skills = set(d_skills) - set(found_skills)
print("Missing Skills : ",missing_skills)

match_missing_score = (len(missing_skills)/len(d_skills))*100
print(f"Missing score : {match_missing_score:.2f}%")
# Out:
#      <input type="file" id="files-7409b594-ee2e-44fe-a129-dd6a2503cbb0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7409b594-ee2e-44fe-a129-dd6a2503cbb0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
